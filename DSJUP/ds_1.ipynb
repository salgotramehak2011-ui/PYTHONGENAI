# %%
import pandas as pd

# %%
data = pd.Series([100,200,300,400],index = ['x','y','z','w'])
data
# Out:
# x    100
# y    200
# z    300
# w    400
# dtype: int64

# %%
a = 10
b = 30
print(a+b)
# Out:
# 40

# %%
print(a*b)
# Out:
# 300

# %%
def funcs():
    print("hello")

# %%
 funcs()
# Out:
# hello

# %% [markdown]
# ## Pandas:

# %%
# data-- 2 types
# 1d data -- Series
# 2d data -- DataFrames

# %%
# Series-- [],{}

# %%
s1 = pd.Series([45,85,'hello',True,12,11,19])
print(s1)
# Out:
# 0       45
# 1       85
# 2    hello
# 3     True
# 4       12
# 5       11
# 6       19
# dtype: object

# %%
s2 = pd.Series([12,45,66,32,11])
s2
# Out:
# 0    12
# 1    45
# 2    66
# 3    32
# 4    11
# dtype: int64

# %%
s3 = pd.Series([55,45,12,90,88,76],index = [5,6,7,8,9,10])
s3
# Out:
# 5     55
# 6     45
# 7     12
# 8     90
# 9     88
# 10    76
# dtype: int64

# %%
s4 = pd.Series([i**2 for i in range(5,15)],index = [i for i in range(5,15)])
s4
# Out:
# 5      25
# 6      36
# 7      49
# 8      64
# 9      81
# 10    100
# 11    121
# 12    144
# 13    169
# 14    196
# dtype: int64

# %%
s4 = pd.Series([i for i in range(5,15)],index = [i**2 for i in range(5,15)])
s4
# Out:
# 25      5
# 36      6
# 49      7
# 64      8
# 81      9
# 100    10
# 121    11
# 144    12
# 169    13
# 196    14
# dtype: int64

# %% [markdown]
# ### Access-- [],.

# %%
s2
# Out:
# 0    12
# 1    45
# 2    66
# 3    32
# 4    11
# dtype: int64

# %%
s2[: 1]
# Out:
# 0    12
# dtype: int64

# %%
s2[1]
# Out:
# 45

# %%
s2[3]
# Out:
# 32

# %%
s3[7]
# Out:
# 12

# %%
s4
# Out:
# 25      5
# 36      6
# 49      7
# 64      8
# 81      9
# 100    10
# 121    11
# 144    12
# 169    13
# 196    14
# dtype: int64

# %%
# s4[0]---Error

# %%
alp = pd.Series([55,45,12,90,88,76],index = ['a','b','c','d','e','f'])
alp
# Out:
# a    55
# b    45
# c    12
# d    90
# e    88
# f    76
# dtype: int64

# %%
alp['a']
# Out:
# 55

# %%
alp['b']
# Out:
# 45

# %%
alp.e
# Out:
# 88

# %%
s2.loc[:]
# Out:
# 0    12
# 1    45
# 2    66
# 3    32
# 4    11
# dtype: int64

# %%
s2.loc[: 2]
# Out:
# 0    12
# 1    45
# 2    66
# dtype: int64

# %%
s2.iloc[: 2]
# Out:
# 0    12
# 1    45
# dtype: int64

# %%
alp
# Out:
# a    55
# b    45
# c    12
# d    90
# e    88
# f    76
# dtype: int64

# %%
alp.loc['a':'e']
# Out:
# a    55
# b    45
# c    12
# d    90
# e    88
# dtype: int64

# %%
# alp.iloc['a']--Error

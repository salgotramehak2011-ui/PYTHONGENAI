# %%
sent= ['the glass of milk',
       'the glass of juice',
       'the cup of tea',
       'he is a good boy',
       'he is a good developer',
       'you are very smart']

# %%
! pip install tensorflow
# Out:
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras.preprocessing.text import one_hot
# pip install tensorflow # -- tensorflow pypi

# %%
vocab_size=50

# %%
one_hot_sent= [one_hot(i,vocab_size) for i in sent]
one_hot_sent
# Out:
# [[22, 38, 46, 45],
#  [22, 38, 46, 7],
#  [22, 35, 46, 10],
#  [8, 7, 46, 23, 37],
#  [8, 7, 46, 23, 21],
#  [1, 2, 7, 17]]

# %%
# word embedding  -- this layer is responsible for converting wordlayer to vector.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding

# %%
sent_length = 7

# %%
embedded_docs= pad_sequences(one_hot_sent,maxlen=sent_length,padding='pre') # padding- post, pre
embedded_docs
# Out:
# array([[ 0,  0,  0, 22, 38, 46, 45],
#        [ 0,  0,  0, 22, 38, 46,  7],
#        [ 0,  0,  0, 22, 35, 46, 10],
#        [ 0,  0,  8,  7, 46, 23, 37],
#        [ 0,  0,  8,  7, 46, 23, 21],
#        [ 0,  0,  0,  1,  2,  7, 17]], dtype=int32)

# %%
model=Sequential()
model.add(Embedding(vocab_size,5,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\manuj\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# array([[[-0.0122455 ,  0.01294344,  0.00883548,  0.03790792,
#          -0.01098477],
#         [-0.0122455 ,  0.01294344,  0.00883548,  0.03790792,
#          -0.01098477],
#         [-0.0122455 ,  0.01294344,  0.00883548,  0.03790792,
#          -0.01098477],
#         [ 0.01492444, -0.04195361,  0.0102749 ,  0.00110598,
#          -0.01259484],
#         [ 0.03193143, -0.04051063,  0.02162066,  0.02257789,
#          -0.03396393],
#         [ 0.03396178, -0.0428802 , -0.00408936, -0.00306374,
#           0.04093497],
#         [-0.04233992,  0.03860958,  0.04140246,  0.00354993,
#           0.04841008]],
#
#        [[-0.0122455 ,  0.01294344,  0.00883548,  0.03790792,
#          -0.01098477],
#         [-0.0122455 ,  0.01294344,  0.00883548,  0.03790792,
#          -0.01098477],
#         [-0.0122455 ,  0.01294344,  0.00883548,  0.03790792,
#          -0.01098477],
#         [ 0.01492444, -0.04195361,  0.0102749 ,  0.00110598,
# ...

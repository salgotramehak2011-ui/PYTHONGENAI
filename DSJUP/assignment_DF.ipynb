# %%
import pandas as pd

# %%
# Question 1(download dataset)
df = pd.read_csv("neet_data.csv")
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
# Question 2(Import CSV and Show Column information and total rows and column)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  object
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  object
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  object
#  5   user_description     36510 non-null  object
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  object
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   object
#  11  tweet                47381 non-null  object
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 4.4+ MB

# %%
print('Column information:')
df.columns
# Out:
# Column information:
# Index(['created_at', 'retweet_count', 'source', 'user_id', 'user_name',
#        'user_description', 'user_follower_count', 'user_friends_count',
#        'user_location', 'user_verified', 'user_url', 'tweet',
#        'length_of_tweet'],
#       dtype='object')

# %%
print('Total rows and columns:')
df.shape
# Out:
# Total rows and columns:
# (47381, 13)

# %%
# Question 3 (sort the dataset with highest retweet to low)
sorted_value = df.sort_values('retweet_count',ascending  = False )
sorted_value
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 33534  2020-11-07 16:45:39              0      Twitter Web App
# 33533  2020-11-07 16:46:12              0   Twitter for iPhone
# 13611  2020-10-27 01:23:03              0  Twitter for Android
# 33531  2020-11-07 16:48:10              0  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
# Question 4(show the)
df[['source','retweet_count','user_name','tweet','created_at','user_url']]
# Out:
#                     source  retweet_count               user_name  \
# 0      Twitter for Android            141                    Rumi
# 1       Twitter for iPhone              1              Tom Bewick
# 2          Twitter Web App            141                Lemonade
# 3      Twitter for Android            141                 The Rus
# 4      Twitter for Android              0            Sakshi Yadav
# ...                    ...            ...                     ...
# 47376  Twitter for Android              0             neet_fad_do
# 47377  Twitter for Android           1700  Yarutai - Garbage NEET
# 47378  Twitter for Android            167                 Raushan
# 47379  Twitter for Android            270               Vijaykant
# 47380  Twitter for Android              0                  Icarus
#
#                                                    tweet           created_at  \
# 0      RT @Kwa_Mamkhize: I am giving away R5K to 100 ...  2020-10-31 14:10:28
# ...

# %%
print('Highest Value of retweet count:')
df.retweet_count.idxmax()
# Out:
# Highest Value of retweet count:
# 32860

# %%
# Question 5(highest top 10 retweet count value print along with text heading like)
top_value = df.sort_values(by='retweet_count',ascending=False).head(10)
sum_value = top_value['retweet_count'].sum()
print('TOP 10 Retweet sum is:',sum_value)
# Out:
# TOP 10 Retweet sum is: 2652225

# %%
# Question 6 (

# %%
# Question 7

# %%
# Question 8

# %%
# Question 9 (tell total null values count of each column)
print('Total null values count of each column:')
df.isnull().sum()
# Out:
# Total null values count of each column:
# created_at                 0
# retweet_count              0
# source                    19
# user_id                    0
# user_name                  1
# user_description       10871
# user_follower_count        0
# user_friends_count         0
# user_location          21134
# user_verified              0
# user_url               38101
# tweet                      0
# length_of_tweet            0
# dtype: int64

# %%
# Question 10 (fill user description as ytwitter user if it is NA value on original DF)

# %%
import pandas as pd

# %%
data = pd.Series([100,200,300,400],index = ['x','y','z','w'])
data.loc['y']
# Out:
# 200

# %%
data.iloc[1]
# Out:
# 200

# %%
data.loc[['x','w']]
# Out:
# x    100
# w    400
# dtype: int64

# %%
data.iloc[-1]
# Out:
# 400

# %%
data.loc['y':'z']
# Out:
# y    200
# z    300
# dtype: int64

# %%
new_data = pd.Series([10,20,30,40,50],index = [1,2,3,4,5])
new_data.iloc[2]
# Out:
# 30

# %%
new_data.loc[2]
# Out:
# 20

# %%
data.x
# Out:
# 100
